# %% [markdown]
# # Scripts divers

# %%
import pandas as pd
from IPython.display import display, HTML

flights_index = ['airline',
'airline_id',
'source_airport',
'source_airport_id',
'destination_airport',
'destination_airport_id',
'codeshare',
'stops',
'equipment']

airport_index = ['airport_id',
'name',
'city',
'country',
'iata',
'icao',
'latitude',
'longitude',
'altitude',
'timezone',
'dst',
'tz_database_time',
'zone_type',
'source']

airports = pd.read_csv('https://raw.githubusercontent.com/jpatokal/openflights/master/data/airports.dat',
                      names=airport_index)

flights = pd.read_csv('https://raw.githubusercontent.com/jpatokal/openflights/master/data/routes.dat', names=flights_index)


display(HTML(flights.head().to_html()))
display(HTML(airports.head().to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>airline</th>
#       <th>airline_id</th>
#       <th>source_airport</th>
#       <th>source_airport_id</th>
#       <th>destination_airport</th>
#       <th>destination_airport_id</th>
#       <th>codeshare</th>
#       <th>stops</th>
#       <th>equipment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2B</td>
#       <td>410</td>
#       <td>AER</td>
#       <td>2965</td>
#       <td>KZN</td>
#       <td>2990</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>CR2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2B</td>
#       <td>410</td>
#       <td>ASF</td>
#       <td>2966</td>
#       <td>KZN</td>
#       <td>2990</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>CR2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2B</td>
#       <td>410</td>
#       <td>ASF</td>
#       <td>2966</td>
# ...

# %%
simple_flights = flights[['source_airport','destination_airport','airline_id','equipment']]
simple_airports = airports[['iata','name','city','country','latitude', 'longitude', 'altitude']]
french_airports = simple_airports[simple_airports['country'] == 'France']

# %%
def old_join_flight_to_airport(flights, airports) :
    src = flights.set_index('source_airport').join(airports.set_index('iata'),how='right')
    dest = src.set_index('destination_airport').join(airports.set_index('iata'), how='right', lsuffix='_src', rsuffix='_dest')
    return dest




def join_flight_to_airport(flights, airports) :
    src = pd.merge(flights, airports, left_on=['source_airport'], right_on=['iata'])
    dest = pd.merge(src, airports, left_on=['destination_airport'], right_on=['iata'],suffixes=('_src','_dest'))
    return dest

# %%
france_flights = join_flight_to_airport(simple_flights, french_airports)
# Out:
# Index(['source_airport', 'destination_airport', 'airline_id', 'equipment',
#        'iata_src', 'name_src', 'city_src', 'country_src', 'latitude_src',
#        'longitude_src', 'altitude_src', 'iata_dest', 'name_dest', 'city_dest',
#        'country_dest', 'latitude_dest', 'longitude_dest', 'altitude_dest'],
#       dtype='object')
#     airline_id source_airport destination_airport          city_src  \
# 0         1203            BOD                 LIL          Bordeaux
# 1         2297            BOD                 LIL          Bordeaux
# 2         1203            LYS                 LIL              Lyon
# 3         1203            MPL                 LIL       Montpellier
# 4         1203            TLS                 LIL          Toulouse
# 5         2297            TLS                 LIL          Toulouse
# 6         1203            BIA                 LIL            Bastia
# 7        20577            BIA                 LIL            Bastia
# ...

# %%
france_flights[['airline_id','source_airport', 'destination_airport']].to_csv('french_flights.csv')

# %%
french_airports[french_airports['iata'].str.len() > 2].to_csv('french_airports.csv')

# %%
import sys
# !{sys.executable} -m pip install lxml ;

# %%
main_frecnh_airports = pd.read_html('https://fr.wikipedia.org/wiki/Liste_des_a%C3%A9roports_les_plus_fr%C3%A9quent%C3%A9s_en_France',
            index_col=0, attrs={"class":"wikitable"})[0]
# Out:
# { "id": 0 } {1}
# { "id": 1 } {2}

# %%
a = main_frecnh_airports[[1,2]]
to_print = []
for idx, code in enumerate(a.values):
    print(f'{{ "id": {code[1]}, "label": "{code[1]}", "group"="airport" }},' )
# Out:
# { "id": 0, "label": "CodeIATA", "group"="airport" },
# { "id": 1, "label": "CDG", "group"="airport" },
# { "id": 2, "label": "ORY", "group"="airport" },
# { "id": 3, "label": "NCE", "group"="airport" },
# { "id": 4, "label": "LYS", "group"="airport" },
# { "id": 5, "label": "TLS", "group"="airport" },
# { "id": 6, "label": "MRS", "group"="airport" },
# { "id": 7, "label": "BSLMLHEAP", "group"="airport" },
# { "id": 8, "label": "BOD", "group"="airport" },
# { "id": 9, "label": "NTE", "group"="airport" },
# { "id": 10, "label": "BVA", "group"="airport" },
# { "id": 11, "label": "PTP", "group"="airport" },
# { "id": 12, "label": "RUN", "group"="airport" },
# { "id": 13, "label": "FDF", "group"="airport" },
# { "id": 14, "label": "LIL", "group"="airport" },
# { "id": 15, "label": "MPL", "group"="airport" },
# { "id": 16, "label": "AJA", "group"="airport" },
# { "id": 17, "label": "BIA", "group"="airport" },
# { "id": 18, "label": "PPT", "group"="airport" },
# ...

# %%
selection = france_flights[france_flights.index.isin(a[2].values)]
for flight in selection.values :
    print(f'{{ "from": {idx}, "label": "{code[1]}", "group"="airport" }},' )
# Out:
#     Airline ID    Equipment                                     Name_src  \
# AJA       3613          ATR                      Avignon-Caumont Airport
# AJA      20577          717                       Brest Bretagne Airport
# AJA      20577          717                    Bordeaux-Mérignac Airport
# AJA       2297          319  EuroAirport Basel-Mulhouse-Freiburg Airport
# AJA       1203          AT5                       Toul Rosières Air Base
# AJA       2297          319      Charles de Gaulle International Airport
# AJA      20577          717                       Caen-Carpiquet Airport
# AJA       1203          AT5                      Castres-Mazamet Airport
# AJA       2684          320                        Lille-Lesquin Airport
# AJA      20577          717                        Lille-Lesquin Airport
# AJA        137          320                   Lyon Saint-Exupéry Airport
# AJA        596          320                   Lyon Saint-Exupéry Airport
# ...

# %%
codes = ["CDG",
"ORY",
"NCE",
"LYS",
"TLS",
"MRS",
"BSLMLHEAP",
"BOD",
"NTE",
"BVA",
"PTP",
"RUN",
"FDF",
"LIL",
"MPL",
"AJA",
"BIA",
"PPT",
"SXB",
"BIQ",
"BES",
"FSC",
"RNS",
"PUF",
"NOU",
"CAY",
"TLN",
"LDE",
"GEA",
"PGF",
"CCF",
"CFE",
"DZA",
"GNB",
"CLY",
"EGC",
"LIG",
"BOB",
"ETZ",
"RFP",
"BZR",
"SFG",
"LRH",
"FNI"]

import random

for from_code in codes:
    for nb in range(1,random.randint(1,5)):
        to_id   = random.randint(0,len(codes)-1)
        to_code = codes[to_id]
        if to_code == from_code:
            continue
        print(f'{{ "from": "{from_code}", "to": "{to_code}", "label": "FOO-{from_id}-{to_id}"}},')
# Out:
# { "from": "CDG", "to": "LDE", "label": "FOO-29-27"},
# { "from": "CDG", "to": "PPT", "label": "FOO-29-17"},
# { "from": "CDG", "to": "ETZ", "label": "FOO-29-38"},
# { "from": "ORY", "to": "PPT", "label": "FOO-29-17"},
# { "from": "NCE", "to": "ORY", "label": "FOO-29-1"},
# { "from": "NCE", "to": "BOD", "label": "FOO-29-7"},
# { "from": "NCE", "to": "BIA", "label": "FOO-29-16"},
# { "from": "LYS", "to": "AJA", "label": "FOO-29-15"},
# { "from": "LYS", "to": "BOB", "label": "FOO-29-37"},
# { "from": "LYS", "to": "LRH", "label": "FOO-29-42"},
# { "from": "LYS", "to": "PGF", "label": "FOO-29-29"},
# { "from": "TLS", "to": "GEA", "label": "FOO-29-28"},
# { "from": "TLS", "to": "BES", "label": "FOO-29-20"},
# { "from": "BSLMLHEAP", "to": "BOD", "label": "FOO-29-7"},
# { "from": "BOD", "to": "LYS", "label": "FOO-29-3"},
# { "from": "NTE", "to": "BES", "label": "FOO-29-20"},
# { "from": "NTE", "to": "NOU", "label": "FOO-29-24"},
# { "from": "BVA", "to": "BOB", "label": "FOO-29-37"},
# ...

# %%
def join_flight_to_french_airport(flights, airports) :
    src = flights.set_index('Source airport').join(airports.set_index('IATA'),how='right')
    dest = src.set_index('Destination airport').join(airports.set_index('IATA'), how='right', lsuffix='_src', rsuffix='_dest')
    return dest
